# %%
#--> Libraries Used
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
#--> Reading the file
dataset = pd.read_csv('C:/Users/vrajm/Desktop/Equity/Google.csv')
#--> Displaying only the first 5 rows of the Data
dataset.head(5)
# Out:
#         Date    Open    High     Low    Close    Volume  Ex-Dividend  \
# 0  8/19/2004  100.01  104.06   95.96  100.335  44659000          0.0
# 1  8/20/2004  101.01  109.08  100.50  108.310  22834300          0.0
# 2  8/23/2004  110.76  113.48  109.05  109.400  18256100          0.0
# 3  8/24/2004  111.24  111.60  103.57  104.870  15247300          0.0
# 4  8/25/2004  104.76  108.00  103.88  106.000   9188600          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0            1  50.159839  52.191109  48.128568   50.322842     44659000
# 1            1  50.661387  54.708881  50.405597   54.322689     22834300
# 2            1  55.551482  56.915693  54.693835   54.869377     18256100
# 3            1  55.792225  55.972783  51.945350   52.597363     15247300
# 4            1  52.542193  54.167209  52.100830   53.164113      9188600

# %%
#-->
a = dataset['High'].max()
a
z= dataset.loc[dataset['High']==a]
z
print('The maximum High for google was on', z['Date'].item(), 'with the value of', z['High'].item(),'.')
# Out:
# The maximum High for google was on 2/26/2014 with the value of 1228.88 .

# %%
#-->
b = dataset['Low'].min()
b
x= dataset.loc[dataset['Low']==b]
x
print('The minimum Low for google was on', x['Date'].item(), 'with the value of', x['Low'].item(),'.')
# Out:
# The minimum Low for google was on 8/19/2004 with the value of 95.96 .

# %%
#--> Rempoving the attribute 'Split Ratio' as it contains ame value in the whole data
del dataset['Split Ratio']

# %%
#-->Data Set without split ratio
dataset.head(5)
# Out:
#         Date    Open    High     Low    Close    Volume  Ex-Dividend  \
# 0  8/19/2004  100.01  104.06   95.96  100.335  44659000          0.0
# 1  8/20/2004  101.01  109.08  100.50  108.310  22834300          0.0
# 2  8/23/2004  110.76  113.48  109.05  109.400  18256100          0.0
# 3  8/24/2004  111.24  111.60  103.57  104.870  15247300          0.0
# 4  8/25/2004  104.76  108.00  103.88  106.000   9188600          0.0
#
#    Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0  50.159839  52.191109  48.128568   50.322842     44659000
# 1  50.661387  54.708881  50.405597   54.322689     22834300
# 2  55.551482  56.915693  54.693835   54.869377     18256100
# 3  55.792225  55.972783  51.945350   52.597363     15247300
# 4  52.542193  54.167209  52.100830   53.164113      9188600

# %%
#-->Finding Correlation between all the attributes
u = dataset.corr()
u
# Out:
#                  Open      High       Low     Close    Volume  Ex-Dividend  \
# Open         1.000000  0.999705  0.999566  0.999277 -0.526805     0.001177
# High         0.999705  1.000000  0.999514  0.999629 -0.523185     0.002026
# Low          0.999566  0.999514  1.000000  0.999700 -0.533264     0.001047
# Close        0.999277  0.999629  0.999700  1.000000 -0.528669     0.001033
# Volume      -0.526805 -0.523185 -0.533264 -0.528669  1.000000    -0.009345
# Ex-Dividend  0.001177  0.002026  0.001047  0.001033 -0.009345     1.000000
# Adj. Open    0.733222  0.732420  0.733275  0.732773 -0.558889     0.020027
# Adj. High    0.732091  0.731656  0.732299  0.732046 -0.556840     0.020976
# Adj. Low     0.733943  0.733296  0.734538  0.734033 -0.562534     0.019829
# Adj. Close   0.732733  0.732334  0.733324  0.733190 -0.559904     0.019881
# Adj. Volume -0.526805 -0.523185 -0.533264 -0.528669  1.000000    -0.009345
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Open          0.733222   0.732091  0.733943    0.732733    -0.526805
# High          0.732420   0.731656  0.733296    0.732334    -0.523185
# Low           0.733275   0.732299  0.734538    0.733324    -0.533264
# Close         0.732773   0.732046  0.734033    0.733190    -0.528669
# Volume       -0.558889  -0.556840 -0.562534   -0.559904     1.000000
# Ex-Dividend   0.020027   0.020976  0.019829    0.019881    -0.009345
# Adj. Open     1.000000   0.999871  0.999809    0.999684    -0.558889
# Adj. High     0.999871   1.000000  0.999788    0.999835    -0.556840
# Adj. Low      0.999809   0.999788  1.000000    0.999871    -0.562534
# Adj. Close    0.999684   0.999835  0.999871    1.000000    -0.559904
# Adj. Volume  -0.558889  -0.556840 -0.562534   -0.559904     1.000000

# %%
#--. Correlation with self is replaced by NaN
rep=u.replace(1, np.nan)
rep
# Out:
#                  Open      High       Low     Close    Volume  Ex-Dividend  \
# Open              NaN  0.999705  0.999566  0.999277 -0.526805     0.001177
# High         0.999705       NaN  0.999514  0.999629 -0.523185     0.002026
# Low          0.999566  0.999514       NaN  0.999700 -0.533264     0.001047
# Close        0.999277  0.999629  0.999700       NaN -0.528669     0.001033
# Volume      -0.526805 -0.523185 -0.533264 -0.528669       NaN    -0.009345
# Ex-Dividend  0.001177  0.002026  0.001047  0.001033 -0.009345          NaN
# Adj. Open    0.733222  0.732420  0.733275  0.732773 -0.558889     0.020027
# Adj. High    0.732091  0.731656  0.732299  0.732046 -0.556840     0.020976
# Adj. Low     0.733943  0.733296  0.734538  0.734033 -0.562534     0.019829
# Adj. Close   0.732733  0.732334  0.733324  0.733190 -0.559904     0.019881
# Adj. Volume -0.526805 -0.523185 -0.533264 -0.528669       NaN    -0.009345
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Open          0.733222   0.732091  0.733943    0.732733    -0.526805
# High          0.732420   0.731656  0.733296    0.732334    -0.523185
# Low           0.733275   0.732299  0.734538    0.733324    -0.533264
# Close         0.732773   0.732046  0.734033    0.733190    -0.528669
# Volume       -0.558889  -0.556840 -0.562534   -0.559904          NaN
# Ex-Dividend   0.020027   0.020976  0.019829    0.019881    -0.009345
# Adj. Open          NaN   0.999871  0.999809    0.999684    -0.558889
# Adj. High     0.999871        NaN  0.999788    0.999835    -0.556840
# Adj. Low      0.999809   0.999788       NaN    0.999871    -0.562534
# Adj. Close    0.999684   0.999835  0.999871         NaN    -0.559904
# Adj. Volume  -0.558889  -0.556840 -0.562534   -0.559904          NaN

# %%
#--> Correlation Matrix (NEW)
rep
# Out:
#                  Open      High       Low     Close    Volume  Ex-Dividend  \
# Open              NaN  0.999705  0.999566  0.999277 -0.526805     0.001177
# High         0.999705       NaN  0.999514  0.999629 -0.523185     0.002026
# Low          0.999566  0.999514       NaN  0.999700 -0.533264     0.001047
# Close        0.999277  0.999629  0.999700       NaN -0.528669     0.001033
# Volume      -0.526805 -0.523185 -0.533264 -0.528669       NaN    -0.009345
# Ex-Dividend  0.001177  0.002026  0.001047  0.001033 -0.009345          NaN
# Adj. Open    0.733222  0.732420  0.733275  0.732773 -0.558889     0.020027
# Adj. High    0.732091  0.731656  0.732299  0.732046 -0.556840     0.020976
# Adj. Low     0.733943  0.733296  0.734538  0.734033 -0.562534     0.019829
# Adj. Close   0.732733  0.732334  0.733324  0.733190 -0.559904     0.019881
# Adj. Volume -0.526805 -0.523185 -0.533264 -0.528669       NaN    -0.009345
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Open          0.733222   0.732091  0.733943    0.732733    -0.526805
# High          0.732420   0.731656  0.733296    0.732334    -0.523185
# Low           0.733275   0.732299  0.734538    0.733324    -0.533264
# Close         0.732773   0.732046  0.734033    0.733190    -0.528669
# Volume       -0.558889  -0.556840 -0.562534   -0.559904          NaN
# Ex-Dividend   0.020027   0.020976  0.019829    0.019881    -0.009345
# Adj. Open          NaN   0.999871  0.999809    0.999684    -0.558889
# Adj. High     0.999871        NaN  0.999788    0.999835    -0.556840
# Adj. Low      0.999809   0.999788       NaN    0.999871    -0.562534
# Adj. Close    0.999684   0.999835  0.999871         NaN    -0.559904
# Adj. Volume  -0.558889  -0.556840 -0.562534   -0.559904          NaN

# %%
#--> Maximum correlation of Open value with High value (Same can be done with other attributes as required)
rep.loc[rep['Open']==rep['Open'].max()]
# Out:
#           Open  High       Low     Close    Volume  Ex-Dividend  Adj. Open  \
# High  0.999705   NaN  0.999514  0.999629 -0.523185     0.002026    0.73242
#
#       Adj. High  Adj. Low  Adj. Close  Adj. Volume
# High   0.731656  0.733296    0.732334    -0.523185

# %%
#--> Heatmap of correlation matrix [cmap represents the color combination]
sns.heatmap(rep,  cmap='ocean_r')
mlt.show()
